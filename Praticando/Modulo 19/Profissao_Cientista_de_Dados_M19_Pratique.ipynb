# %% [markdown]
# # **MÓDULO 19**
# # Exercício: Estatística Aplicada

# %% [markdown]
# **Efetividade de Duas Estratégias de Ensino**
#
# Imagine que uma escola esteja avaliando a eficácia de duas estratégias de ensino de matemática para alunos do ensino médio. Eles querem determinar se há uma diferença significativa no desempenho médio dos alunos entre as duas estratégias.

# %% [markdown]
# # **Hipóteses:**
#
# * Hipótese nula (H0): A média das notas dos alunos na estratégia A é igual à média das notas dos alunos na estratégia B.
# * Hipótese alternativa (H1): A média das notas na Estratégia B é maior do que a média das notas na Estratégia A.

# %% [markdown]
# # **Dados:**
#
# * Amostra da Estratégia A: Notas de 50 alunos que receberam a Estratégia A.
# * Amostra da Estratégia B: Notas de 50 alunos que receberam a Estratégia B.

# %% [markdown]
# Usaremos um teste Z para comparar as médias das notas entre as duas amostras.

# %% [markdown]
# Se o p-valor do teste Z for menor que um nível de significância pré-determinado (por exemplo, α = 0.05), rejeitamos a hipótese nula e concluímos que há uma diferença significativa nas médias das notas entre as duas estratégias de ensino.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import norm

# %% [markdown]
# Os dados são criados a seguir:

# %%
# Definindo médias e desvios padrão para as notas nas duas estratégias
media_estrategia_A = 70
desvio_padrao_estrategia_A = 10

media_estrategia_B = 75
desvio_padrao_estrategia_B = 12

# Gerando as amostras de notas para cada estratégia de ensino da nossa base
np.random.seed(0)  # Para garantir a reprodutibilidade dos resultados
amostra_estrategia_A = np.random.normal(loc=media_estrategia_A, scale=desvio_padrao_estrategia_A, size=50)
amostra_estrategia_B = np.random.normal(loc=media_estrategia_B, scale=desvio_padrao_estrategia_B, size=50)

print("Notas da Estratégia A:", amostra_estrategia_A[:5])
print("Notas da Estratégia B:", amostra_estrategia_B[:5])
# Out:
# Notas da Estratégia A: [87.64052346 74.00157208 79.78737984 92.40893199 88.6755799 ]
# Notas da Estratégia B: [64.25440127 79.64282997 68.87033835 60.83241379 74.66181326]

# %% [markdown]
# # 1) De acordo com as informações analisadas o nosso teste é unilateral á direita, esquerda ou bicaudal? Justifique.

# %%
# Sua justificativa aqui
# O teste é unilateral à direita, pois estamos testando se a média da Estratégia B é significativamente maior do que a da Estratégia A.

# %% [markdown]
# # 2) Calcule as médias para as duas amostragens e as variâncias. Quais insights você pode retirar comparando os dados?

# %%
# Seu código aqui
# Calculando as médias e variâncias das amostras
media_amostra_A = np.mean(amostra_estrategia_A)
media_amostra_B = np.mean(amostra_estrategia_B)

variancia_amostra_A = np.var(amostra_estrategia_A, ddof=1)  # Variância amostral (n-1)
variancia_amostra_B = np.var(amostra_estrategia_B, ddof=1)  # Variância amostral (n-1)

# Exibindo os resultados
print(f"Média da Estratégia A: {media_amostra_A:.2f}")
print(f"Média da Estratégia B: {media_amostra_B:.2f}")
print(f"Variância da Estratégia A: {variancia_amostra_A:.2f}")
print(f"Variância da Estratégia B: {variancia_amostra_B:.2f}")
# Out:
# Média da Estratégia A: 71.41
# Média da Estratégia B: 74.75
# Variância da Estratégia A: 129.27
# Variância da Estratégia B: 110.47

# %% [markdown]
# **Insights sobre os dados das estratégias de ensino**
#
# Média das notas:
# - A Estratégia B tem uma média de 74.75, enquanto a Estratégia A tem 71.41.
# - Isso sugere que, em média, a Estratégia B leva a notas mais altas.
#
# Dispersão das notas (Variância):
# - A Estratégia A tem uma variância maior (129.27) do que a Estratégia B (110.47).
# - Isso significa que as notas na Estratégia A são mais dispersas, ou seja, há maior variação entre os alunos.
# - A Estratégia B apresenta notas mais consistentes entre os alunos.
#
#
# Conclusões preliminares:
# - A Estratégia B parece ser mais eficaz para melhorar as notas.
# - A Estratégia B também tem menos variabilidade, indicando que os alunos apresentam um desempenho mais homogêneo.

# %% [markdown]
# # 3) Imprima os resultados da estatística do teste Z, p value e indique se rejeitaremos ou não a hipótese nula. Justifique sua resposta.

# %%
# Seu código aqui

# Tamanho das amostras
n_A = len(amostra_estrategia_A)
n_B = len(amostra_estrategia_B)

# Cálculo do valor do teste Z
z_score = (media_amostra_B - media_amostra_A) / np.sqrt((variancia_amostra_A / n_A) + (variancia_amostra_B / n_B))

# Cálculo do valor-p (teste unilateral à direita)
p_value = 1 - norm.cdf(z_score)

# Exibindo os resultados
print("Estatística de teste Z:", z_score)
print("p-valor:", p_value)

# Comparar o p-valor com o nível de significância
nivel_significancia = 0.05
if p_value < nivel_significancia:
    print("Rejeitamos a hipótese nula: há uma diferença significativa entre as médias das notas das estratégias A e B.")
else:
    print("Não rejeitamos a hipótese nula: não há evidências suficientes para concluir que há uma diferença significativa entre as médias das notas das estratégias A e B.")
# Out:
# Estatística de teste Z: 1.5267455833477102
# p-valor: 0.06341214386181693
# Não rejeitamos a hipótese nula: não há evidências suficientes para concluir que há uma diferença significativa entre as médias das notas das estratégias A e B.

# %% [markdown]
# Apesar da média da Estratégia B ser maior, a diferença não é estatisticamente significativa ao nível de 5%. Isso significa que não podemos afirmar com confiança que a Estratégia B é realmente superior à Estratégia A — a diferença pode ter ocorrido por acaso.

# %% [markdown]
# # 4) Para finalizar monte o gráfico da distribuição da estatística do nosso teste Z e explique o que pode ser observado através dele.

# %%
# Seu código aqui

# Configurações do gráfico
fig, ax = plt.subplots(figsize=(10, 5))

# Valores de X e Y para plotar a distribuição
x = np.linspace(-3, 3, 1000)
# x = np.linspace(-3, 3, 1000): Esta linha cria um array x de 1000 pontos igualmente espaçados no intervalo de -3 a 3. Esse intervalo foi escolhido para abranger uma ampla gama de valores típicos para a estatística de teste Z, que segue uma distribuição normal padrão
y = stats.norm.pdf(x, 0, 1)
# y = stats.norm.pdf(x, 0, 1): Esta linha calcula os valores de densidade de probabilidade para cada ponto no array x com base na distribuição normal padrão.

# Plotando a distribuição normal padrão
ax.plot(x, y, label='Distribuição Normal Padrão')

# Marcação do valor observado da estatística do teste
ax.vlines(x=[z_score], ymin=0, ymax=stats.norm.pdf(z_score, 0, 1),
          colors='r', linestyles='dotted', label='Valor observado da estatística de teste')

# Área crítica
critical_region = stats.norm.ppf(0.025), stats.norm.ppf(0.975)
ax.fill_between(x, y, where=(x < critical_region[0]) | (x > critical_region[1]), color='gray', alpha=0.3, label='Área crítica')

# Legenda e rótulos
plt.legend()
plt.xlabel('Valor da Estatística de Teste Z')
plt.ylabel('Densidade')
plt.title('Distribuição da Estatística de Teste Z')
plt.grid(True)

# Exibindo o gráfico
plt.show()

# %% [markdown]
# Explicando o gráfico:
#
# **Curva Azul - Distribuição Normal Padrão**
#
# - Representa a distribuição normal com média 0 e desvio padrão 1.
# - A área sob essa curva indica a probabilidade de ocorrência de diferentes valores de Z.
#
#
# **Linha Vermelha Tracejada - Valor Observado da Estatística Z**
#
# - Indica o valor da estatística de teste Z calculado para a comparação das amostras.
# - A posição dessa linha determina se devemos rejeitar ou não a hipótese nula.
#
#
# **Áreas Cinzas - Regiões Críticas**
#
# - Representam as regiões onde a hipótese nula seria rejeitada para um teste bicaudal com α=0.05.
# - Se o valor de Z cair dentro dessas áreas (abaixo de -1.96 ou acima de 1.96), rejeitamos.
#
#
# **Interpretação do Resultado**
#
# - No gráfico, o valor de Z observado está fora da região crítica à esquerda, mas próximo da fronteira superior.
# - Se o valor de Z estiver na região não crítica (área branca), não há evidências suficientes para rejeitar.
# - Se ele estivesse dentro da área cinza, rejeitaríamos, indicando uma diferença estatisticamente significativa entre as estratégias.
